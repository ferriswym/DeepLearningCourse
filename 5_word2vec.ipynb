# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5234, 3081, 12, 6, 195, 2, 3134, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'originated', 'a', 'as', 'term', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['term', 'a', 'anarchism', 'originated', 'as', 'of', 'term', 'originated']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.169640
# Nearest to years: orange, recall, earnhardt, hafez, letsie, arabidopsis, countermeasures, oeuvre,
# Nearest to at: fb, roddick, public, dummar, scandals, bowled, taff, desai,
# Nearest to some: craving, ppm, combines, priestly, naxos, pommel, palpatine, ecologically,
# Nearest to and: phenomenology, deva, subtractive, arrive, sidewise, airplay, bad, few,
# Nearest to states: marshalling, commercial, condominiums, memetics, yerevan, summoning, modifying, waterman,
# Nearest to they: mahor, magazine, barat, inca, fined, kahn, gaud, slaughterhouse,
# Nearest to is: michinaga, ayyash, pieter, shake, requires, reeves, entail, grilled,
# Nearest to d: casino, governments, machete, phoenician, tightening, their, gegen, constituci,
# Nearest to first: nsync, treblinka, holomorphic, smothers, articulations, dragging, zionist, lungs,
# Nearest to with: finnic, united, expresses, predatory, collectivism, vos, gardeners, tincture,
# Nearest to zero: sunburn, chapel, fee, rescuing, erection, informally, demonstrable, sql,
# Nearest to of: siddha, periodical, fundraiser, nemesis, migrated, anglicized, zen, beware,
# Nearest to this: angered, intimidation, primitive, gallons, pasha, breakthroughs, rorty, revived,
# Nearest to has: sharman, moment, truthfulness, pineapples, pythons, futile, inns, armchair,
# Nearest to s: shabbat, reggie, furlong, methamphetamine, soaked, blanchard, processors, franchisee,
# Nearest to UNK: extravagant, abdicating, cheapest, esv, durch, residency, guerre, collective,
# Average loss at step 2000: 4.365602
# Average loss at step 4000: 3.872917
# Average loss at step 6000: 3.789206
# Average loss at step 8000: 3.691137
# Average loss at step 10000: 3.613066
# Nearest to years: orange, eddy, recall, blvd, burlesque, convulsions, ashes, ow,
# Nearest to at: during, in, gaulish, normalize, by, jt, vilna, against,
# Nearest to some: many, these, craving, chelmsford, congestive, other, superpower, vainly,
# Nearest to and: or, d, umayyads, were, colonnade, in, steered, s,
# Nearest to states: condominiums, attractive, commercial, internationalization, marshalling, modifying, tailed, marius,
# Nearest to they: he, it, she, not, slaughterhouse, still, we, procurator,
# Nearest to is: was, are, has, approximate, be, but, amato, cueing,
# Nearest to d: b, and, aquileia, fortran, seaplane, seer, arbitrators, governments,
# Nearest to first: discogs, hamilton, dddddd, guam, dragging, beverages, phenomenon, salaries,
# Nearest to with: in, finnic, assuring, by, from, einhard, for, since,
# Nearest to zero: seven, eight, six, nine, five, four, three, two,
# Nearest to of: in, stratford, nasdaq, religiously, on, fsb, second, from,
# Nearest to this: it, the, which, angered, jocular, christi, vitry, camus,
# Nearest to has: had, is, was, sharman, have, inns, hollywood, julius,
# Nearest to s: his, bengali, and, furlong, cypriot, hemoglobin, sept, laminated,
# Nearest to UNK: references, ration, mortars, co, novel, leno, iron, elite,
# Average loss at step 12000: 3.609165
# Average loss at step 14000: 3.571525
# Average loss at step 16000: 3.411079
# Average loss at step 18000: 3.456339
# Average loss at step 20000: 3.544888
# Nearest to years: blvd, eddy, orange, ashes, taxpayer, predominant, recall, biota,
# Nearest to at: in, during, on, against, under, with, from, and,
# Nearest to some: many, these, all, several, congestive, superpower, other, craving,
# Nearest to and: or, but, from, at, for, although, which, campos,
# Nearest to states: internationalization, commercial, condominiums, teenager, precipitated, summoning, adc, waged,
# Nearest to they: he, we, there, it, who, she, not, however,
# Nearest to is: was, are, has, were, be, but, by, annual,
# Nearest to d: b, aquileia, sindh, buoyed, meritocratic, fortran, opus, seer,
# Nearest to first: discogs, hamilton, next, earliest, last, proofing, rabban, southerners,
# Nearest to with: palaces, finnic, in, at, arid, against, between, from,
# Nearest to zero: five, seven, six, four, three, eight, nine, two,
# Nearest to of: codecs, for, duplications, same, highlanders, berne, belloc, discrediting,
# Nearest to this: it, which, the, jocular, christi, a, drenched, not,
# Nearest to has: had, have, is, was, ignacy, believing, preis, hypostasis,
# Nearest to s: laminated, subunit, doug, aleksandr, station, saterland, drove, furlong,
# Nearest to UNK: sen, mcdonough, references, discouraged, preferentially, livia, iron, habilis,
# Average loss at step 22000: 3.504448
# Average loss at step 24000: 3.489566
# Average loss at step 26000: 3.481894
# Average loss at step 28000: 3.482692
# Average loss at step 30000: 3.505952
# Nearest to years: days, months, times, year, eddy, predominant, blvd, taxpayer,
# Nearest to at: in, during, participating, softly, under, hereafter, vilna, on,
# Nearest to some: many, these, several, all, most, any, other, the,
# Nearest to and: or, but, including, in, who, like, northeasterly, of,
# Nearest to states: internationalization, commercial, condominiums, kingdom, teenager, melted, adc, waged,
# Nearest to they: we, he, there, you, not, it, who, these,
# Nearest to is: was, has, are, had, does, be, but, were,
# Nearest to d: b, aquileia, fortran, nederland, knoxville, distract, synchronicity, ascendancy,
# Nearest to first: last, earliest, second, next, discogs, ductus, dddddd, hamilton,
# Nearest to with: between, against, when, in, among, for, including, finnic,
# Nearest to zero: five, seven, eight, four, six, nine, three, two,
# Nearest to of: in, servicio, including, for, and, entire, nasdaq, from,
# Nearest to this: it, which, that, there, collectivization, what, tasked, haba,
# Nearest to has: had, have, is, was, having, aise, cannibalism, nilsson,
# Nearest to s: his, hemoglobin, bengali, her, laminated, lentils, polymerase, integrable,
# Nearest to UNK: l, soaps, ctor, accuracy, oxidative, loan, habilis, jubal,
# Average loss at step 32000: 3.499935
# Average loss at step 34000: 3.498232
# Average loss at step 36000: 3.454129
# Average loss at step 38000: 3.305456
# Average loss at step 40000: 3.430426
# Nearest to years: days, months, times, year, decades, fennel, superjanet, courses,
# Nearest to at: on, during, under, in, against, softly, for, amyraut,
# Nearest to some: many, these, several, any, most, different, both, those,
# Nearest to and: or, but, bailiwicks, like, legendary, umayyads, including, les,
# Nearest to states: kingdom, internationalization, countries, commercial, waged, nations, waterfowl, condominiums,
# Nearest to they: we, you, there, he, not, it, these, she,
# Nearest to is: was, are, has, if, scalp, governance, be, geometrically,
# Nearest to d: b, c, ascendancy, UNK, chew, nederland, huguenot, ergative,
# Nearest to first: second, last, next, discogs, piloting, trotsky, earliest, ductus,
# Nearest to with: against, finnic, between, by, including, when, anacletus, rterbuch,
# Nearest to zero: five, seven, eight, nine, four, six, three, two,
# Nearest to of: in, premises, formless, belloc, kana, adolescence, entire, aleksandr,
# Nearest to this: which, it, that, the, another, any, he, haba,
# Nearest to has: had, have, was, having, is, ignacy, aise, holliday,
# Nearest to s: his, ericaceae, lolita, batted, maglev, did, bedford, her,
# Nearest to UNK: e, prolonged, von, b, grinding, la, van, h,
# Average loss at step 42000: 3.433222
# Average loss at step 44000: 3.451750
# Average loss at step 46000: 3.449189
# Average loss at step 48000: 3.351902
# Average loss at step 50000: 3.384616
# Nearest to years: days, months, times, decades, year, people, emi, fennel,
# Nearest to at: during, on, against, participating, in, under, vilna, softly,
# Nearest to some: many, several, these, both, most, all, any, those,
# Nearest to and: or, but, while, including, than, although, fossil, snub,
# Nearest to states: kingdom, waged, knife, internationalization, countries, nations, party, waterfowl,
# Nearest to they: he, we, there, she, you, it, not, who,
# Nearest to is: was, has, are, although, remains, while, be, backus,
# Nearest to d: b, c, ascendancy, ergative, xxi, devoting, meritocratic, nederland,
# Nearest to first: next, last, second, entire, ductus, final, discogs, greatest,
# Nearest to with: between, babbitt, by, expresses, finnic, in, commited, geats,
# Nearest to zero: seven, five, eight, four, six, three, nine, two,
# Nearest to of: in, and, firewalls, berne, mathematische, including, jacksonville, adolescence,
# Nearest to this: which, it, the, haba, he, another, there, colouring,
# Nearest to has: had, have, was, is, ignacy, having, berklee, since,
# Nearest to s: cypriot, dhimma, massacred, and, his, while, however, spaghetti,
# Nearest to UNK: von, www, de, displeasure, la, le, livia, sensual,
# Average loss at step 52000: 3.438879
# Average loss at step 54000: 3.431448
# Average loss at step 56000: 3.437050
# Average loss at step 58000: 3.395512
# Average loss at step 60000: 3.399699
# Nearest to years: days, months, decades, year, times, centuries, rounds, seconds,
# Nearest to at: in, within, under, during, throughout, on, participating, dn,
# Nearest to some: many, several, these, any, all, both, most, those,
# Nearest to and: or, but, than, although, including, in, without, like,
# Nearest to states: kingdom, nations, countries, internationalization, condominiums, knife, waterfowl, clarinets,
# Nearest to they: we, there, he, you, she, these, i, not,
# Nearest to is: was, are, has, makes, be, remains, although, but,
# Nearest to d: b, c, xxi, e, meritocratic, ascendancy, ergative, archivist,
# Nearest to first: last, second, next, ductus, discogs, earliest, only, same,
# Nearest to with: between, when, finnic, assuring, against, within, among, and,
# Nearest to zero: five, seven, eight, four, six, three, nine, two,
# Nearest to of: in, for, same, guadalajara, codecs, entire, nasdaq, and,
# Nearest to this: it, which, that, there, the, vitry, some, itself,
# Nearest to has: had, have, was, is, having, ignacy, aise, berklee,
# Nearest to s: cypriot, relapsed, subunit, lott, lesotho, moveable, laminated, hemoglobin,
# Nearest to UNK: fitz, martial, nacional, tanistry, convenience, juliet, grinding, abernethy,
# Average loss at step 62000: 3.237795
# Average loss at step 64000: 3.253352
# Average loss at step 66000: 3.404095
# Average loss at step 68000: 3.389776
# Average loss at step 70000: 3.355192
# Nearest to years: days, months, decades, times, year, centuries, percent, seconds,
# Nearest to at: boredom, after, under, during, in, reaches, honors, acropolis,
# Nearest to some: many, several, these, all, various, any, those, most,
# Nearest to and: or, while, of, but, including, than, widows, however,
# Nearest to states: kingdom, nations, countries, clarinets, state, knife, teenager, condominiums,
# Nearest to they: we, he, there, you, she, it, these, never,
# Nearest to is: was, has, are, be, although, being, sunt, does,
# Nearest to d: b, meritocratic, ergative, xxi, devoting, j, p, h,
# Nearest to first: last, second, next, original, same, earliest, entire, final,
# Nearest to with: between, finnic, when, cooler, against, by, resembling, babbitt,
# Nearest to zero: five, six, eight, four, seven, nine, three, two,
# Nearest to of: including, and, in, for, include, browne, or, original,
# Nearest to this: it, which, the, that, another, what, there, some,
# Nearest to has: had, have, is, was, having, since, includes, ignacy,
# Nearest to s: moveable, degrades, essentials, leonel, hemoglobin, isbn, laminated, glossaries,
# Nearest to UNK: ncaa, pondering, realistic, blooms, honestly, slates, topics, stomach,
# Average loss at step 72000: 3.382951
# Average loss at step 74000: 3.347069
# Average loss at step 76000: 3.320261
# Average loss at step 78000: 3.358547
# Average loss at step 80000: 3.379548
# Nearest to years: days, months, decades, times, year, centuries, percent, past,
# Nearest to at: in, throughout, on, timurid, during, around, kanons, reaches,
# Nearest to some: many, several, these, most, all, various, any, certain,
# Nearest to and: or, but, vermin, including, kiel, than, byu, faltered,
# Nearest to states: kingdom, nations, countries, clarinets, condominiums, reforestation, knife, hippolyte,
# Nearest to they: we, he, you, there, she, it, who, these,
# Nearest to is: was, has, remains, are, although, does, contains, backus,
# Nearest to d: b, p, ascendancy, ergative, h, j, xxi, adrian,
# Nearest to first: second, last, next, third, only, original, same, final,
# Nearest to with: between, when, against, babbitt, finnic, burman, including, josaphat,
# Nearest to zero: five, seven, six, four, eight, three, nine, two,
# Nearest to of: including, in, entire, duplications, original, kana, at, nasser,
# Nearest to this: which, it, the, that, what, itself, some, another,
# Nearest to has: had, have, is, was, having, since, believing, contains,
# Nearest to s: troubling, cypriot, isbn, sept, batted, implicitly, colloquially, reggie,
# Nearest to UNK: rupp, maclaurin, disappearing, financi, asp, l, duodecimal, weir,
# Average loss at step 82000: 3.408219
# Average loss at step 84000: 3.410859
# Average loss at step 86000: 3.389910
# Average loss at step 88000: 3.352434
# Average loss at step 90000: 3.365370
# Nearest to years: days, decades, months, year, times, centuries, seconds, percent,
# Nearest to at: on, under, in, during, timurid, after, bounced, acropolis,
# Nearest to some: many, several, these, all, any, most, this, those,
# Nearest to and: or, but, vermin, including, while, byu, in, although,
# Nearest to states: kingdom, nations, countries, condominiums, reforestation, clarinets, hippolyte, knife,
# Nearest to they: we, he, there, you, she, it, these, cumbric,
# Nearest to is: was, has, are, remains, makes, although, be, becomes,
# Nearest to d: b, ascendancy, ergative, nd, h, zero, xxi, adrian,
# Nearest to first: last, second, next, original, earliest, same, final, entire,
# Nearest to with: between, babbitt, when, against, including, bung, in, from,
# Nearest to zero: five, eight, seven, six, four, two, nine, three,
# Nearest to of: for, including, in, from, kana, and, browne, jesuits,
# Nearest to this: it, which, some, the, itself, rx, berlioz, he,
# Nearest to has: had, have, is, having, was, contains, includes, since,
# Nearest to s: cypriot, isbn, his, boney, nelson, acct, andreas, ilmarinen,
# Nearest to UNK: sur, hearses, mancala, ambiguously, fv, obscure, rightarrow, eridu,
# Average loss at step 92000: 3.401211
# Average loss at step 94000: 3.250337
# Average loss at step 96000: 3.357523
# Average loss at step 98000: 3.244347
# Average loss at step 100000: 3.351028
# Nearest to years: days, decades, months, year, times, centuries, percent, seconds,
# Nearest to at: on, during, in, under, reaches, timurid, after, bounced,
# Nearest to some: many, several, these, any, all, those, certain, few,
# Nearest to and: or, but, when, although, while, however, including, like,
# Nearest to states: kingdom, nations, countries, clarinets, condominiums, reforestation, knife, internationalization,
# Nearest to they: we, there, he, you, she, it, not, these,
# Nearest to is: was, has, are, remains, be, contains, became, represents,
# Nearest to d: b, c, h, ergative, y, ascendancy, adrian, transports,
# Nearest to first: last, next, second, third, earliest, entire, final, fourth,
# Nearest to with: between, when, expresses, into, including, josaphat, babbitt, finnic,
# Nearest to zero: five, four, seven, six, eight, nine, two, three,
# Nearest to of: entire, in, including, hibernation, retainers, original, from, and,
# Nearest to this: which, it, itself, another, he, what, haba, the,
# Nearest to has: had, have, is, was, having, contains, since, equaled,
# Nearest to s: his, cypriot, degrades, hemoglobin, reggie, atomists, isbn, moveable,
# Nearest to UNK: ration, von, et, boils, disulfide, disappearing, playable, habilis,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
data_index = 0

def generate_CBOW_batch(batch_size, skip_window):
    global data_index # 使用全局数据索引
    batch = np.ndarray(shape=(batch_size, 2 * skip_window), dtype=np.int32) # 初始化
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    span = 2 * skip_window + 1 # [ skip_window target skip_window ]  定义一次抽取样本数据的长度
    buffer = collections.deque(maxlen=span) # 定义数据缓存，为队列
    for _ in range(span): # 抽取初始样本放入数据缓存buffer中
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    for i in range(batch_size): #
        target = skip_window # target label at the center of the buffer
        for j in range(skip_window):
            batch[i, j] = buffer[j]
            batch[i, 2*skip_window - j - 1] = buffer[span - j - 1]
        labels[i, 0] = buffer[target]
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for skip_window in [1, 2]:
    data_index = 0
    batch, labels = generate_CBOW_batch(batch_size=8, skip_window=skip_window)
    print('\nskip_window = %d:' % (skip_window))
    print(len(batch))
    print('    batch:', [reverse_dictionary[bi] for bi in batch.reshape(8*2*skip_window)])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# skip_window = 1:
# 8
#     batch: ['anarchism', 'as', 'originated', 'a', 'as', 'term', 'a', 'of', 'term', 'abuse', 'of', 'first', 'abuse', 'used', 'first', 'against']
#     labels: ['originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used']
#
# skip_window = 2:
# 8
#     batch: ['anarchism', 'originated', 'a', 'term', 'originated', 'as', 'term', 'of', 'as', 'a', 'of', 'abuse', 'a', 'term', 'abuse', 'first', 'term', 'of', 'first', 'used', 'of', 'abuse', 'used', 'against', 'abuse', 'first', 'against', 'early', 'first', 'used', 'early', 'working']
#     labels: ['as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against']

# %%
#Train a CBOW model.
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size, 2*skip_window])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embedsum = tf.Variable(tf.zeros([embedding_size]))
  for i in range(2*skip_window):
    embed = tf.nn.embedding_lookup(embeddings, train_dataset[:,i])
    embedsum += embed
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embedsum,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))
# Out:
# (128, 2)
# (128, 2)

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_CBOW_batch(
      batch_size, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.424654
# Nearest to system: requiem, ceiling, mastiff, avowed, blas, opolska, y, bartender,
# Nearest to and: sammon, herat, tops, optimisation, claudine, bede, programmable, tilde,
# Nearest to were: citizenship, opiates, pepys, ystok, insights, coriander, genres, lok,
# Nearest to have: octagon, pedagogy, chose, goldeneye, samsung, corneille, aortic, mordred,
# Nearest to into: limburg, flatland, condor, emerson, backlash, furthering, keen, sunspots,
# Nearest to b: carnahan, protagonist, mjf, dix, sackville, halo, breda, dorms,
# Nearest to been: disassembly, pelias, aphorisms, tragically, ebenezer, autocode, joris, lush,
# Nearest to over: rampage, lukewarm, bram, oligosaccharides, afternoon, sensitivity, connective, emulsions,
# Nearest to war: cayman, revolver, loving, persisted, primaries, uprising, uucp, harmonically,
# Nearest to not: riverfront, competitor, complication, tambo, course, sites, specimens, chengdu,
# Nearest to he: solicitation, decorations, oldsmobile, cbm, avoiding, offa, graviton, candide,
# Nearest to s: drills, haliotis, demyelinating, sutcliffe, crucifixes, catalana, logical, herbie,
# Nearest to two: jelly, spoilage, nests, ex, soir, whomever, reginae, insidious,
# Nearest to it: sayings, reminder, indymedia, mammals, abolish, beginnings, bavarian, witnessed,
# Nearest to or: dirt, lends, eesti, prolog, musings, antilles, bessarabia, perens,
# Nearest to with: isis, revert, dollfuss, corot, turnaround, hawthorn, burgesses, concubines,
# Average loss at step 2000: 3.920228
# Average loss at step 4000: 3.565258
# Average loss at step 6000: 3.402860
# Average loss at step 8000: 3.283832
# Average loss at step 10000: 3.191952
# Nearest to system: avowed, ceiling, mastiff, dilution, subduction, libra, canned, resignations,
# Nearest to and: or, but, in, of, during, blockbuster, prasad, cx,
# Nearest to were: are, was, have, had, is, quicksort, transports, be,
# Nearest to have: had, has, be, were, are, acclaimed, togo, pontificia,
# Nearest to into: from, through, condor, between, activated, fronts, with, on,
# Nearest to b: d, dix, excitable, migrating, env, natively, nassau, bardeen,
# Nearest to been: was, beaton, mbta, be, tragically, is, degenerative, supplant,
# Nearest to over: mantua, counterweight, etat, emulsions, lukewarm, joyful, realist, jocular,
# Nearest to war: cayman, revolver, detachment, equivalents, ministerial, quin, uprising, merina,
# Nearest to not: still, to, riverfront, often, complication, lasted, they, iir,
# Nearest to he: she, it, they, who, there, covertly, but, solicitation,
# Nearest to s: his, mlp, reichswehr, drills, or, fence, aml, aspires,
# Nearest to two: three, four, five, six, nine, eight, seven, one,
# Nearest to it: he, there, this, which, they, she, often, but,
# Nearest to or: and, than, but, eminently, underdeveloped, antilles, s, is,
# Nearest to with: between, in, by, accompaniment, for, roque, into, of,
# Average loss at step 12000: 3.133319
# Average loss at step 14000: 3.017519
# Average loss at step 16000: 3.108830
# Average loss at step 18000: 3.053341
# Average loss at step 20000: 3.081626
# Nearest to system: ceiling, canned, flora, libra, systems, insider, masses, absorption,
# Nearest to and: but, or, in, of, however, he, during, who,
# Nearest to were: are, was, had, have, is, those, been, transports,
# Nearest to have: had, has, be, were, are, having, glottalized, previously,
# Nearest to into: through, from, between, across, during, under, in, condor,
# Nearest to b: d, natively, excitable, env, heretics, nassau, stag, nancy,
# Nearest to been: become, was, be, already, were, beaton, mbta, tragically,
# Nearest to over: through, counterweight, discoverers, idiom, stanislavski, etat, mantua, slowly,
# Nearest to war: cayman, revolver, northumbria, amt, merina, equivalents, entrusted, talons,
# Nearest to not: still, often, always, they, lasted, desperately, riverfront, to,
# Nearest to he: she, it, they, there, who, never, and, then,
# Nearest to s: his, aspires, mlp, carracci, whose, australian, the, of,
# Nearest to two: three, four, six, eight, seven, five, one, nine,
# Nearest to it: he, there, she, this, they, which, who, that,
# Nearest to or: and, than, underdeveloped, tsr, niki, while, but, although,
# Nearest to with: between, by, in, when, as, without, accompaniment, into,
# Average loss at step 22000: 3.062653
# Average loss at step 24000: 2.905902
# Average loss at step 26000: 3.031241
# Average loss at step 28000: 3.003180
# Average loss at step 30000: 2.948422
# Nearest to system: systems, masses, occurrence, nist, threats, absorption, phagspa, canned,
# Nearest to and: or, but, however, while, including, in, of, for,
# Nearest to were: are, have, was, had, is, be, been, being,
# Nearest to have: had, has, were, are, be, according, include, having,
# Nearest to into: through, from, across, between, in, under, grandmaster, with,
# Nearest to b: d, stag, misfits, f, carnahan, evaluations, kwh, wallenberg,
# Nearest to been: become, be, was, were, mbta, already, tragically, is,
# Nearest to over: through, between, idiom, within, clearances, knoxville, lukewarm, discoverers,
# Nearest to war: cayman, revolver, wars, merina, northumbria, entrusted, antiwar, equivalents,
# Nearest to not: still, generally, always, often, never, joked, now, riverfront,
# Nearest to he: she, it, they, there, who, never, covertly, arawak,
# Nearest to s: his, whose, cuauht, my, her, aspires, and, their,
# Nearest to two: three, four, six, seven, eight, five, one, nine,
# Nearest to it: he, she, this, there, but, they, still, which,
# Nearest to or: and, than, but, while, though, tsr, although, leonards,
# Nearest to with: between, by, in, into, when, bartholomew, across, sl,
# Average loss at step 32000: 2.955817
# Average loss at step 34000: 2.969711
# Average loss at step 36000: 2.926704
# Average loss at step 38000: 2.762877
# Average loss at step 40000: 2.901067
# Nearest to system: systems, masses, bhfiann, absorption, phagspa, flirt, vassar, resignations,
# Nearest to and: or, while, but, including, of, although, see, on,
# Nearest to were: are, was, have, became, including, had, while, be,
# Nearest to have: had, has, were, are, include, be, having, according,
# Nearest to into: through, from, across, between, under, within, off, on,
# Nearest to b: d, evaluations, stag, mies, migrating, n, giulia, misfits,
# Nearest to been: become, be, already, were, tragically, was, classically, recently,
# Nearest to over: through, within, across, on, between, idiom, mantua, salamanca,
# Nearest to war: cayman, wars, revolver, merina, sdi, equivalents, jacobson, northumbria,
# Nearest to not: always, still, never, now, generally, riverfront, actually, mostly,
# Nearest to he: she, it, they, who, there, never, dylan, later,
# Nearest to s: aspires, tenochtitl, isbn, whose, and, cutters, australian, his,
# Nearest to two: three, six, four, five, seven, eight, one, nine,
# Nearest to it: he, she, there, this, they, still, determines, which,
# Nearest to or: and, while, but, than, though, judaizers, although, underdeveloped,
# Nearest to with: between, in, when, by, without, using, including, transcribing,
# Average loss at step 42000: 2.909194
# Average loss at step 44000: 2.868146
# Average loss at step 46000: 2.909136
# Average loss at step 48000: 2.938655
# Average loss at step 50000: 2.884749
# Nearest to system: systems, canned, literals, user, game, masses, technology, threats,
# Nearest to and: or, but, while, including, although, however, for, of,
# Nearest to were: are, was, had, have, while, is, been, tend,
# Nearest to have: had, has, are, were, having, include, be, according,
# Nearest to into: through, from, across, within, between, under, off, over,
# Nearest to b: d, n, excitable, misfits, mummification, giulia, c, string,
# Nearest to been: become, be, already, was, were, recently, grown, beaton,
# Nearest to over: within, through, between, across, about, idiom, into, out,
# Nearest to war: wars, cayman, merina, revolver, rat, entrusted, jacobson, arab,
# Nearest to not: still, actually, never, always, now, they, also, generally,
# Nearest to he: she, it, they, there, who, we, dylan, publicized,
# Nearest to s: whose, his, aspires, your, cuauht, and, mlp, arbitrator,
# Nearest to two: three, seven, five, four, six, eight, one, nine,
# Nearest to it: he, she, this, there, they, itself, we, determines,
# Nearest to or: and, but, of, although, for, including, though, while,
# Nearest to with: between, in, including, for, within, during, among, without,
# Average loss at step 52000: 2.891611
# Average loss at step 54000: 2.819528
# Average loss at step 56000: 2.815164
# Average loss at step 58000: 2.808411
# Average loss at step 60000: 2.858219
# Nearest to system: systems, structure, technique, absorption, process, threats, bhfiann, flora,
# Nearest to and: or, but, including, however, although, while, of, during,
# Nearest to were: are, have, was, had, including, is, those, include,
# Nearest to have: had, has, were, are, be, having, include, previously,
# Nearest to into: through, from, between, within, across, in, with, under,
# Nearest to b: d, env, natively, hempstead, mies, lichtenberg, migrating, evaluations,
# Nearest to been: become, be, was, already, grown, begun, recently, were,
# Nearest to over: through, within, across, idiom, between, out, off, about,
# Nearest to war: wars, cayman, merina, jacobson, rat, curtail, mclean, cofactors,
# Nearest to not: now, still, actually, never, always, almost, generally, nor,
# Nearest to he: she, it, they, who, there, i, we, eventually,
# Nearest to s: whose, cuauht, isbn, his, meteorological, australian, ganz, amaranthus,
# Nearest to two: three, four, six, five, seven, eight, nine, one,
# Nearest to it: he, she, there, this, they, what, itself, still,
# Nearest to or: and, than, but, while, via, though, without, per,
# Nearest to with: between, in, using, during, including, within, by, to,
# Average loss at step 62000: 2.697979
# Average loss at step 64000: 2.826514
# Average loss at step 66000: 2.798689
# Average loss at step 68000: 2.798829
# Average loss at step 70000: 2.691145
# Nearest to system: systems, technique, literals, absorption, process, circuit, bhfiann, network,
# Nearest to and: or, including, but, although, while, however, of, like,
# Nearest to were: are, was, have, had, including, tend, is, although,
# Nearest to have: had, has, are, were, having, according, be, include,
# Nearest to into: through, from, within, under, between, across, in, down,
# Nearest to b: d, natively, env, string, c, construed, londoners, mies,
# Nearest to been: become, be, grown, begun, recently, was, already, locally,
# Nearest to over: through, between, idiom, within, connective, across, about, off,
# Nearest to war: wars, cayman, merina, rat, cup, equivalents, jolly, mclean,
# Nearest to not: now, always, never, still, almost, actually, addons, generally,
# Nearest to he: she, it, they, there, we, who, i, publicized,
# Nearest to s: whose, although, his, cuauht, blish, does, yasser, meteorological,
# Nearest to two: three, four, six, seven, five, eight, one, nine,
# Nearest to it: he, she, this, there, they, but, often, which,
# Nearest to or: and, than, though, while, but, including, although, wumpus,
# Nearest to with: between, including, in, during, using, by, when, contains,
# Average loss at step 72000: 2.690588
# Average loss at step 74000: 2.729032
# Average loss at step 76000: 2.771996
# Average loss at step 78000: 2.706574
# Average loss at step 80000: 2.680348
# Nearest to system: systems, circuit, process, structure, network, phenomenon, term, program,
# Nearest to and: or, but, including, although, with, while, however, like,
# Nearest to were: are, have, was, include, had, those, although, tend,
# Nearest to have: had, has, were, be, having, include, are, according,
# Nearest to into: through, within, from, under, across, between, whammy, to,
# Nearest to b: d, env, shehri, horsemen, string, c, insuring, mies,
# Nearest to been: become, be, grown, was, recently, begun, already, classically,
# Nearest to over: through, within, between, across, idiom, around, connective, about,
# Nearest to war: wars, cayman, merina, rat, jacobson, uprising, northumbria, marines,
# Nearest to not: still, actually, never, now, almost, generally, always, mostly,
# Nearest to he: she, it, they, there, who, we, however, never,
# Nearest to s: whose, isbn, his, our, blish, cuauht, dougal, although,
# Nearest to two: three, four, five, six, seven, eight, one, nine,
# Nearest to it: she, he, there, this, they, itself, we, still,
# Nearest to or: and, while, including, though, but, than, although, exceeding,
# Nearest to with: in, between, and, during, using, including, of, via,
# Average loss at step 82000: 2.794118
# Average loss at step 84000: 2.795118
# Average loss at step 86000: 2.650776
# Average loss at step 88000: 2.725034
# Average loss at step 90000: 2.701930
# Nearest to system: systems, circuit, esiason, technique, process, program, structure, project,
# Nearest to and: or, but, although, including, while, of, though, however,
# Nearest to were: are, was, had, have, although, include, is, those,
# Nearest to have: had, has, include, having, be, were, are, require,
# Nearest to into: through, within, from, across, under, between, back, whammy,
# Nearest to b: d, c, n, env, v, michelin, lumberjack, f,
# Nearest to been: become, be, was, grown, begun, were, already, remained,
# Nearest to over: across, around, idiom, about, through, within, off, between,
# Nearest to war: wars, rat, cayman, merina, jacobson, cruz, mclean, xxix,
# Nearest to not: never, actually, always, now, still, generally, they, nothing,
# Nearest to he: she, it, they, there, we, who, never, rallied,
# Nearest to s: whose, isbn, our, blish, mlp, cuauht, my, of,
# Nearest to two: three, four, six, seven, five, eight, nine, one,
# Nearest to it: he, she, this, there, they, itself, however, which,
# Nearest to or: and, though, than, while, although, with, but, without,
# Nearest to with: between, including, in, within, using, or, by, of,
# Average loss at step 92000: 2.711150
# Average loss at step 94000: 2.748504
# Average loss at step 96000: 2.627126
# Average loss at step 98000: 2.721684
# Average loss at step 100000: 2.713739
# Nearest to system: systems, process, technique, phenomenon, curonian, structure, selangor, esiason,
# Nearest to and: or, but, while, although, including, however, though, nor,
# Nearest to were: are, was, have, had, including, include, although, tend,
# Nearest to have: had, has, are, were, having, be, contain, include,
# Nearest to into: through, within, under, across, from, down, between, off,
# Nearest to b: d, c, n, reagent, env, michelin, linebackers, genital,
# Nearest to been: become, be, grown, begun, was, already, tragically, were,
# Nearest to over: around, across, about, idiom, salamanca, off, within, approximately,
# Nearest to war: wars, cayman, eschewed, rat, merina, bian, uprising, jacobson,
# Nearest to not: never, nor, now, actually, still, generally, always, rarely,
# Nearest to he: she, it, they, there, we, later, rallied, who,
# Nearest to s: whose, isbn, meteorological, cuauht, my, panzer, does, and,
# Nearest to two: three, four, five, six, eight, seven, one, nine,
# Nearest to it: he, she, this, there, they, itself, effectively, today,
# Nearest to or: and, while, but, though, than, including, although, whose,
# Nearest to with: between, within, in, via, by, using, for, into,

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])
words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
